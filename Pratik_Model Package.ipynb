# %% [markdown]
# ## Classfication

# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
data=load_iris()

# %%
dataset=pd.DataFrame(data.data,columns=data.feature_names)
dataset['Target']=data['target']
dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
x=dataset.drop(['Target'],axis=1)
y=dataset.Target

# %%
from Pratik_model import smart_classifier
model=smart_classifier(x,y)

# %%
model.accuracy_score()
# Out:
# HistGradientBoostingClassifier(random_state=42)     - 1.0
#
# PassiveAggressiveClassifier(random_state=42)     - 0.9736842105263158
#
# DecisionTreeClassifier(random_state=42)     - 1.0
#
# RandomForestClassifier(random_state=42)     - 1.0
#
# ExtraTreesClassifier(random_state=42)     - 1.0
#
# LogisticRegression(random_state=42)     - 1.0
#
# RidgeClassifier(random_state=42)     - 0.868421052631579
#
# LGBMClassifier(random_state=42)     - 1.0
#
# KNeighborsClassifier()     - 1.0
#
# SVC(random_state=42)     - 1.0
#
# CatBoost Classifier  -  1.0
#
# XGBoost Classifier -  1.0
#
# GaussianNB()     - 1.0

# %%
model.classification_report()
# Out:
#  HistGradientBoostingClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  PassiveAggressiveClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.92      1.00      0.96        11
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
#
#  DecisionTreeClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  RandomForestClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  ExtraTreesClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  LogisticRegression(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  RidgeClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.88      0.64      0.74        11
#            2       0.73      0.92      0.81        12
#
#     accuracy                           0.87        38
#    macro avg       0.87      0.85      0.85        38
# weighted avg       0.88      0.87      0.87        38
#
#
#  LGBMClassifier(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  KNeighborsClassifier()  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  SVC(random_state=42)  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
# CatBoost Classifier -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  XgBoost Classifier -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#  GaussianNB()  -
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        11
#            2       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
model.confusion_matrix()
# Out:
#  HistGradientBoostingClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  PassiveAggressiveClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  1 11]]
#
#  DecisionTreeClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  RandomForestClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  ExtraTreesClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  LogisticRegression(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  RidgeClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0  7  4]
#  [ 0  1 11]]
#
#  LGBMClassifier(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  KNeighborsClassifier()  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  SVC(random_state=42)  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
# CatBoost Classifier   -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
# XgBoost Classifier   -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
#
#  GaussianNB()  -
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]

# %%
model.cross_validation()
# Out:
# HistGradientBoostingClassifier(random_state=42)     -  0.9466666666666667
#
# PassiveAggressiveClassifier(random_state=42)     -  0.8600000000000001
#
# DecisionTreeClassifier(random_state=42)     -  0.9533333333333334
#
# RandomForestClassifier(random_state=42)     -  0.9666666666666668
#
# ExtraTreesClassifier(random_state=42)     -  0.9533333333333334
#
# LogisticRegression(random_state=42)     -  0.9733333333333334
#
# RidgeClassifier(random_state=42)     -  0.8200000000000001
#
# LGBMClassifier(random_state=42)     -  0.9466666666666667
#
# KNeighborsClassifier()     -  0.9733333333333334
#
# SVC(random_state=42)     -  0.9666666666666666
#
# CatBoost Classifier -  0.9666666666666668
#
# XgBoost Classifier -  0.96
#
# GaussianNB()     -  0.9533333333333334

# %%
model.mean_absolute_error()
# Out:
# HistGradientBoostingClassifier(random_state=42)      -  0.0
#
# PassiveAggressiveClassifier(random_state=42)      -  0.02631578947368421
#
# DecisionTreeClassifier(random_state=42)      -  0.0
#
# RandomForestClassifier(random_state=42)      -  0.0
#
# ExtraTreesClassifier(random_state=42)      -  0.0
#
# LogisticRegression(random_state=42)      -  0.0
#
# RidgeClassifier(random_state=42)      -  0.13157894736842105
#
# LGBMClassifier(random_state=42)      -  0.0
#
# KNeighborsClassifier()      -  0.0
#
# SVC(random_state=42)      -  0.0
#
# CatBoost Classifier   -  0.0
#
# XgBoost Classifier    -  0.0
#
# GaussianNB()      -  0.0

# %%
model.mean_squared_error()
# Out:
# HistGradientBoostingClassifier(random_state=42)     -  0.0
#
# PassiveAggressiveClassifier(random_state=42)     -  0.02631578947368421
#
# DecisionTreeClassifier(random_state=42)     -  0.0
#
# RandomForestClassifier(random_state=42)     -  0.0
#
# ExtraTreesClassifier(random_state=42)     -  0.0
#
# LogisticRegression(random_state=42)     -  0.0
#
# RidgeClassifier(random_state=42)     -  0.13157894736842105
#
# LGBMClassifier(random_state=42)     -  0.0
#
# KNeighborsClassifier()     -  0.0
#
# SVC(random_state=42)     -  0.0
#
# CatBoost Classifier  -  0.0
#
# XgBoost Classifier   -  0.0
#
# GaussianNB()     -  0.0

# %%
model.overfitting()
# Out:
# Training Accuracy of HistGradientBoostingClassifier(random_state=42)     -  1.0
# Testing Accuracy  of HistGradientBoostingClassifier(random_state=42)     -  1.0
#
# Training Accuracy of PassiveAggressiveClassifier(random_state=42)     -  0.9285714285714286
# Testing Accuracy  of PassiveAggressiveClassifier(random_state=42)     -  0.9736842105263158
#
# Training Accuracy of DecisionTreeClassifier(random_state=42)     -  1.0
# Testing Accuracy  of DecisionTreeClassifier(random_state=42)     -  1.0
#
# Training Accuracy of RandomForestClassifier(random_state=42)     -  1.0
# Testing Accuracy  of RandomForestClassifier(random_state=42)     -  1.0
#
# Training Accuracy of ExtraTreesClassifier(random_state=42)     -  1.0
# Testing Accuracy  of ExtraTreesClassifier(random_state=42)     -  1.0
#
# Training Accuracy of LogisticRegression(random_state=42)     -  0.9642857142857143
# Testing Accuracy  of LogisticRegression(random_state=42)     -  1.0
#
# Training Accuracy of RidgeClassifier(random_state=42)     -  0.8482142857142857
# Testing Accuracy  of RidgeClassifier(random_state=42)     -  0.868421052631579
#
# Training Accuracy of LGBMClassifier(random_state=42)     -  1.0
# Testing Accuracy  of LGBMClassifier(random_state=42)     -  1.0
#
# Training Accuracy of KNeighborsClassifier()     -  0.9642857142857143
# Testing Accuracy  of KNeighborsClassifier()     -  1.0
#
# Training Accuracy of SVC(random_state=42)     -  0.9553571428571429
# Testing Accuracy  of SVC(random_state=42)     -  1.0
#
# Training Accuracy of CatBoost Classifier    -  1.0
# Testing Accuracy  of CatBoost Classifier    -  1.0
#
# Training Accuracy of XgBoost Classifier    -  1.0
# Testing Accuracy  of XgBoost Classifier    -  1.0
#
# Training Accuracy of GaussianNB()     -  0.9464285714285714
# Testing Accuracy  of GaussianNB()     -  1.0

# %%
model.precision_score()
# Out:
# It is multi-classed problem so for that we are calculating Presicion Score in average = "macro"
#
#
# HistGradientBoostingClassifier(random_state=42)    -  1.0
#
# PassiveAggressiveClassifier(random_state=42)    -  0.9722222222222222
#
# DecisionTreeClassifier(random_state=42)    -  1.0
#
# RandomForestClassifier(random_state=42)    -  1.0
#
# ExtraTreesClassifier(random_state=42)    -  1.0
#
# LogisticRegression(random_state=42)    -  1.0
#
# RidgeClassifier(random_state=42)    -  0.8694444444444445
#
# LGBMClassifier(random_state=42)    -  1.0
#
# KNeighborsClassifier()    -  1.0
#
# SVC(random_state=42)    -  1.0
#
# CatBoost Classifier -  1.0
#
# XgBoost Classifier -  1.0
#
# GaussianNB()    -  1.0

# %%
model.recall_score()
# Out:
# It is multi-classed problem so for that we are calculating Recall Score in average = "macro"
#
#
# HistGradientBoostingClassifier(random_state=42)     -  1.0
#
# PassiveAggressiveClassifier(random_state=42)     -  0.9722222222222222
#
# DecisionTreeClassifier(random_state=42)     -  1.0
#
# RandomForestClassifier(random_state=42)     -  1.0
#
# ExtraTreesClassifier(random_state=42)     -  1.0
#
# LogisticRegression(random_state=42)     -  1.0
#
# RidgeClassifier(random_state=42)     -  0.8510101010101009
#
# LGBMClassifier(random_state=42)     -  1.0
#
# KNeighborsClassifier()     -  1.0
#
# SVC(random_state=42)     -  1.0
#
# CatBoost Classifier -  1.0
#
# XgBoost Classifier -  1.0
#
# GaussianNB()     -  1.0

# %% [markdown]
# ## Regression

# %%
from sklearn.datasets import load_boston
import pandas as pd

data = load_boston()
data
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#         21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#         35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#         19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#         20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#         23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#         33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#         21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#         20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#         23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
#         15.6, 11.8, 13.8, 15.6, 14.6, 17.8, 15.4, 21.5, 19.6, 15.3, 19.4,
#         17. , 15.6, 13.1, 41.3, 24.3, 23.3, 27. , 50. , 50. , 50. , 22.7,
#         25. , 50. , 23.8, 23.8, 22.3, 17.4, 19.1, 23.1, 23.6, 22.6, 29.4,
#         23.2, 24.6, 29.9, 37.2, 39.8, 36.2, 37.9, 32.5, 26.4, 29.6, 50. ,
#         32. , 29.8, 34.9, 37. , 30.5, 36.4, 31.1, 29.1, 50. , 33.3, 30.3,
#         34.6, 34.9, 32.9, 24.1, 42.3, 48.5, 50. , 22.6, 24.4, 22.5, 24.4,
#         20. , 21.7, 19.3, 22.4, 28.1, 23.7, 25. , 23.3, 28.7, 21.5, 23. ,
#         26.7, 21.7, 27.5, 30.1, 44.8, 50. , 37.6, 31.6, 46.7, 31.5, 24.3,
#         31.7, 41.7, 48.3, 29. , 24. , 25.1, 31.5, 23.7, 23.3, 22. , 20.1,
#         22.2, 23.7, 17.6, 18.5, 24.3, 20.5, 24.5, 26.2, 24.4, 24.8, 29.6,
#         42.8, 21.9, 20.9, 44. , 50. , 36. , 30.1, 33.8, 43.1, 48.8, 31. ,
#         36.5, 22.8, 30.7, 50. , 43.5, 20.7, 21.1, 25.2, 24.4, 35.2, 32.4,
#         32. , 33.2, 33.1, 29.1, 35.1, 45.4, 35.4, 46. , 50. , 32.2, 22. ,
#         20.1, 23.2, 22.3, 24.8, 28.5, 37.3, 27.9, 23.9, 21.7, 28.6, 27.1,
#         20.3, 22.5, 29. , 24.8, 22. , 26.4, 33.1, 36.1, 28.4, 33.4, 28.2,
#         22.8, 20.3, 16.1, 22.1, 19.4, 21.6, 23.8, 16.2, 17.8, 19.8, 23.1,
#         21. , 23.8, 23.1, 20.4, 18.5, 25. , 24.6, 23. , 22.2, 19.3, 22.6,
#         19.8, 17.1, 19.4, 22.2, 20.7, 21.1, 19.5, 18.5, 20.6, 19. , 18.7,
#         32.7, 16.5, 23.9, 31.2, 17.5, 17.2, 23.1, 24.5, 26.6, 22.9, 24.1,
#         18.6, 30.1, 18.2, 20.6, 17.8, 21.7, 22.7, 22.6, 25. , 19.9, 20.8,
#         16.8, 21.9, 27.5, 21.9, 23.1, 50. , 50. , 50. , 50. , 50. , 13.8,
#         13.8, 15. , 13.9, 13.3, 13.1, 10.2, 10.4, 10.9, 11.3, 12.3,  8.8,
#          7.2, 10.5,  7.4, 10.2, 11.5, 15.1, 23.2,  9.7, 13.8, 12.7, 13.1,
#         12.5,  8.5,  5. ,  6.3,  5.6,  7.2, 12.1,  8.3,  8.5,  5. , 11.9,
#         27.9, 17.2, 27.5, 15. , 17.2, 17.9, 16.3,  7. ,  7.2,  7.5, 10.4,
#          8.8,  8.4, 16.7, 14.2, 20.8, 13.4, 11.7,  8.3, 10.2, 10.9, 11. ,
#          9.5, 14.5, 14.1, 16.1, 14.3, 11.7, 13.4,  9.6,  8.7,  8.4, 12.8,
#         10.5, 17.1, 18.4, 15.4, 10.8, 11.8, 14.9, 12.6, 14.1, 13. , 13.4,
#         15.2, 16.1, 17.8, 14.9, 14.1, 12.7, 13.5, 14.9, 20. , 16.4, 17.7,
#         19.5, 20.2, 21.4, 19.9, 19. , 19.1, 19.1, 20.1, 19.9, 19.6, 23.2,
#         29.8, 13.8, 13.3, 16.7, 12. , 14.6, 21.4, 23. , 23.7, 25. , 21.8,
#         20.6, 21.2, 19.1, 20.6, 15.2,  7. ,  8.1, 13.6, 20.1, 21.8, 24.5,
#         23.1, 19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9]),
#  'feature_names': array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#         'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7'),
#  'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,000\n        - PTRATIO  pupil-teacher ratio by town\n        - B        1000(Bk - 0.63)^2 where Bk is the proportion of black people by town\n        - LSTAT    % lower status of the population\n        - MEDV     Median value of owner-occupied homes in $1000's\n\n    :Missing Attribute Values: None\n\n    :Creator: Harrison, D. and Rubinfeld, D.L.\n\nThis is a copy of UCI ML housing dataset.\nhttps://archive.ics.uci.edu/ml/machine-learning-databases/housing/\n\n\nThis dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.\n\nThe Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic\nprices and the demand for clean air', J. Environ. Economics & Management,\nvol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics\n...', Wiley, 1980.   N.B. Various transformations are used in the table on\npages 244-261 of the latter.\n\nThe Boston house-price data has been used in many machine learning papers that address regression\nproblems.   \n     \n.. topic:: References\n\n   - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.\n   - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.\n",
#  'filename': 'boston_house_prices.csv',
#  'data_module': 'sklearn.datasets.data'}

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)
df['Target']=data['target']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  Target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
x=df.drop(['Target'],axis=1)
y=df.Target

# %%
from Pratik_model import smart_regressor
model=smart_regressor(x,y)

# %%
model.r2_score()
# Out:
# PassiveAggressiveRegressor(average=3, random_state=42)      -  0.18375392521779588
#
# HistGradientBoostingRegressor(random_state=42)      -  0.8385471254825801
#
# GradientBoostingRegressor(random_state=42)      -  0.8721047222908935
#
# DecisionTreeRegressor(random_state=42)      -  0.761686335812318
#
# RandomForestRegressor(random_state=42)      -  0.8518521336172665
#
# ExtraTreesRegressor(random_state=42)      -  0.8487089009390085
#
# LGBMRegressor(random_state=42)      -  0.843807334877084
#
# Lasso(random_state=42)      -  0.6516957380017043
#
# KNeighborsRegressor()      -  0.639665439953224
#
# LinearRegression()      -  0.6844267283527123
#
# CatBoost Regressor -  0.8704445342370748
#
# XgBoost Regressor -  0.8563261418953055
#
# SVR()      -  0.2962129740673506

# %%
model.mean_absolute_error()
# Out:
# PassiveAggressiveRegressor(average=3, random_state=42)      -  5.960608901376878
#
# HistGradientBoostingRegressor(random_state=42)      -  2.114695207062456
#
# GradientBoostingRegressor(random_state=42)      -  2.0277682484943322
#
# DecisionTreeRegressor(random_state=42)      -  2.808661417322835
#
# RandomForestRegressor(random_state=42)      -  2.1481259842519673
#
# ExtraTreesRegressor(random_state=42)      -  1.9764094488188984
#
# LGBMRegressor(random_state=42)      -  2.0965685177207907
#
# Lasso(random_state=42)      -  3.4246102430971086
#
# KNeighborsRegressor()      -  3.6215748031496067
#
# LinearRegression()      -  3.060939595437034
#
# CatBoost Regressor -  1.8776754503444744
#
# XgBoost Regressor -  2.1403884940260043
#
# SVR()      -  4.4624587836642124

# %%
model.overfitting()
# Out:
# Training Accuracy of PassiveAggressiveRegressor(average=3, random_state=42)     -  0.24358387688580252
# Testing Accuracy  of PassiveAggressiveRegressor(average=3, random_state=42)     -  0.18375392521779588
#
# Training Accuracy of HistGradientBoostingRegressor(random_state=42)     -  0.9753631430979733
# Testing Accuracy  of HistGradientBoostingRegressor(random_state=42)     -  0.8385471254825801
#
# Training Accuracy of GradientBoostingRegressor(random_state=42)     -  0.9785520655757387
# Testing Accuracy  of GradientBoostingRegressor(random_state=42)     -  0.8721047222908935
#
# Training Accuracy of DecisionTreeRegressor(random_state=42)     -  1.0
# Testing Accuracy  of DecisionTreeRegressor(random_state=42)     -  0.761686335812318
#
# Training Accuracy of RandomForestRegressor(random_state=42)     -  0.9800795659663495
# Testing Accuracy  of RandomForestRegressor(random_state=42)     -  0.8518521336172665
#
# Training Accuracy of ExtraTreesRegressor(random_state=42)     -  1.0
# Testing Accuracy  of ExtraTreesRegressor(random_state=42)     -  0.8487089009390085
#
# Training Accuracy of LGBMRegressor(random_state=42)     -  0.9748128927539379
# Testing Accuracy  of LGBMRegressor(random_state=42)     -  0.843807334877084
#
# Training Accuracy of Lasso(random_state=42)     -  0.6948040743556284
# Testing Accuracy  of Lasso(random_state=42)     -  0.6516957380017043
#
# Training Accuracy of KNeighborsRegressor()     -  0.6679090196467314
# Testing Accuracy  of KNeighborsRegressor()     -  0.639665439953224
#
# Training Accuracy of LinearRegression()     -  0.7480872598623441
# Testing Accuracy  of LinearRegression()     -  0.6844267283527123
#
# Training Accuracy of CatBoost Regressor    -  0.8704445342370748
# Testing Accuracy  of CatBoost Regressor    -  0.8704445342370748
#
# Training Accuracy of XgBoost Regressor    -  0.8563261418953055
# Testing Accuracy  of XgBoost Regressor    -  0.8563261418953055
#
# Training Accuracy of SVR()     -  0.1781378369867943
# Testing Accuracy  of SVR()     -  0.2962129740673506

# %%
model.mean_squared_error()
# Out:
# PassiveAggressiveRegressor(average=3, random_state=42)     -  61.409952779493196
#
# HistGradientBoostingRegressor(random_state=42)     -  10.123479084978635
#
# GradientBoostingRegressor(random_state=42)     -  6.208861361528038
#
# DecisionTreeRegressor(random_state=42)     -  10.416078431372549
#
# RandomForestRegressor(random_state=42)     -  7.901513892156864
#
# ExtraTreesRegressor(random_state=42)     -  9.758463235294116
#
# LGBMRegressor(random_state=42)     -  8.338757275893952
#
# Lasso(random_state=42)     -  24.4094897612997
#
# KNeighborsRegressor()     -  25.860125490196076
#
# LinearRegression()     -  24.291119474973456
#
# CatBoost Regressor -  7.723727518105467
#
# XgBoost Regressor -  6.560527271813469
#
# SVR()     -  52.83836576796669

# %%
model.cross_validation()
# Out:
# PassiveAggressiveRegressor(average=3, random_state=42)     -  -0.7802125808074909
#
# HistGradientBoostingRegressor(random_state=42)     -  0.5491141304411663
#
# GradientBoostingRegressor(random_state=42)     -  0.6745677868708551
#
# DecisionTreeRegressor(random_state=42)     -  0.21730795391822397
#
# RandomForestRegressor(random_state=42)     -  0.6270701879637265
#
# ExtraTreesRegressor(random_state=42)     -  0.6387003693953457
#
# LGBMRegressor(random_state=42)     -  0.5799586849005655
#
# Lasso(random_state=42)     -  0.431848787926522
#
# KNeighborsRegressor()     -  -0.31501646812514134
#
# LinearRegression()     -  0.3532759243958772
#
# CatBoost Regressor -  0.6628344862255072
#
# XgBoost Regressor -  0.6460769617602883
#
# SVR()     -  -0.0903070943152309
